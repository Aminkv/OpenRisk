# %% [markdown]
# # Mass Balance Simulation
#
# <p dir="rtl">
# در این مثال برای طراحی مدل دینامیک ساده‌ی موازنه جرم واحدی که نفت خام را دریافت می کند از شبیه سازی استفاده کرده‌ایم.
# </p>

# %%
import numpy as np

# %%
n_simulations = 10000

# %%
feed_crude = 1
